# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        return "Woof!"

    def get_info(self):
        return f"{self.name} is {self.age} years old."
# Example usage:
if __name__ == "__main__":
    my_dog = Dog("Buddy", 3)
    print(my_dog.bark())          # Output: Woof!
    print(my_dog.get_info())      # Output: Buddy is 3 years old.
# Out:
# Woof!
# Buddy is 3 years old.

# %%
class Dog:
    legs = 4
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} says Woof!")

myDog = Dog("Buddy")
print(myDog.name)
print(myDog.legs)
myDog.speak()
# Out:
# Buddy
# 4
# Buddy says Woof!

# %%
Dog.legs
# Out:
# 4

# %% [markdown]
# Static and Instance Methgods in Python

# %%
class WordSet:
    def __init__(self):
        self.words = set()

    def addText(self, text):
        text = self.cleanText(text)
        for word in text.split():
            self.words.add(word)

    def cleanText(self, text):
        #Chaining funcations 
        text = text.replace('!', ' ').replace('.', ' ').replace(',', ' ').replace('?', ' ')
        return text.lower()

WordSet = WordSet()

WordSet.addText("Hi, I\'m Abhi: Here is a sentence I want to add!")
WordSet.addText("Here is another sentence I want to add.")

print(WordSet.words)
# Out:
# {'hi', 'another', 'to', 'abhi:', 'a', 'sentence', 'i', "i'm", 'here', 'add', 'is', 'want'}

# %%
class WordSet:
    replacePuncs = [ '!', '.', ',', '?' ]
    def __init__(self):
        self.words = set()

    def addText(self, text):
        text = self.cleanText(text)
        for word in text.split():
            self.words.add(word)

    def cleanText(text):
        #Chaining funcations 
       for punc in WordSet.replacePuncs:
           text = text.replace(punc, ' ')
       return text.lower()

WordSet = WordSet()

WordSet .addText("Hi, I\'m Abhi: Here is a sentence I want to add!")
WordSet.addText("Here is another sentence I want to add.")

print(WordSet.words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 19
#      15        return text.lower()
#      17 WordSet = WordSet()
# ---> 19 WordSet .addText("Hi, I\'m Abhi: Here is a sentence I want to add!")
#      20 WordSet.addText("Here is another sentence I want to add.")
#      22 print(WordSet.words)
#
# Cell In[5], line 7, in WordSet.addText(self, text)
#       6 def addText(self, text):
# ----> 7     text = self.cleanText(text)
#       8     for word in text.split():
#       9         self.words.add(word)
#
# TypeError: WordSet.cleanText() takes 1 positional argument but 2 were given

# %% [markdown]
# Class Inheritance

# %%
class Dog:
    __leg = 4
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(self.name + " says Woof!")
    
    def getLeg(self):
        return self.__leg
    
class Chihuahua(Dog):
    def speak(self):
        print(f'{self.name} says Yip!')

# %%
dog = Chihuahua("Dog")
dog.speak()
# Out:
# Dog says Yip!

# %%
myList = list()

# %%
class UniqueList(list):
    def append ( self, item ):
        if item not in self:
            super().append(item)
UniqueList = UniqueList()
UniqueList.append(1)
UniqueList.append(2)
UniqueList.append(1)

print(UniqueList)
# Out:
# [1, 2]

# %% [markdown]
# Try/Except

# %%
try:
    1/0
except Exception as e:
    print(type(e))
# Out:
# <class 'ZeroDivisionError'>
