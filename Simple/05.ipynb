# %%
A = True
B = False

if A:
    print("A is True")
# Out:
# A is True

# %%
from datetime import datetime
now = datetime.now()

print("Current date and time:", now)
# Out:
# Current date and time: 2026-01-26 05:29:09.601806
