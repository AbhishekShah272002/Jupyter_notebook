# %%
x = 12
y = 5
print(x/y)
# Out:
# 2.4

# %%
#Write a Python program to display student details (Name, Roll No, Marks) using formatted output.
'''This program displays student details in a formatted way.'''
name = "John Doe"
roll_no = 23
marks = 88.5
print("Student Details:")
print("Name: {}".format(name))
print("Roll No: {}".format(roll_no))
print("Marks: {:.2f}".format(marks))
# Out:
# Student Details:
# Name: John Doe
# Roll No: 23
# Marks: 88.50

# %%
'''Write a program to swap two numbers using: 

a temporary variable 
multiple assignments '''
# Swapping using a temporary variable
a = 10
b = 20
temp = a
a = b
b = temp
print("After swapping using a temporary variable:")
print("a =", a)
print("b =", b)
# Swapping using multiple assignments
x = 30
y = 40
x, y = y, x
print("After swapping using multiple assignments:")
print("x =", x)
print("y =", y)
# Out:
# After swapping using a temporary variable:
# a = 20
# b = 10
# After swapping using multiple assignments:
# x = 40
# y = 30

# %%
'''Write a program to calculate Simple Interest by taking principal, rate, and time from the user'''
# Taking inputs from the user
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest: "))
time = float(input("Enter the time in years: "))
# Calculating Simple Interest
simple_interest = (principal * rate * time) / 100
print("The Simple Interest is:", simple_interest)
# Out:
# The Simple Interest is: 257.0

# %%
'''Write a program to find the maximum of three numbers using comparison operators.  '''
# Taking inputs from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))
# Finding the maximum
if num1 >= num2 and num1 >= num3:
    maximum = num1
elif num2 >= num1 and num2 >= num3:
    maximum = num2
else:
    maximum = num3
print("The maximum of the three numbers is:", maximum)
# Out:
# The maximum of the three numbers is: 78.0

# %%
'''Write a program to check whether a number is even or odd. '''
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is even.

# %%
'''Write a program to convert temperature from Celsius to Fahrenheit. '''
celsius = float(input("Enter the temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("The temperature in Fahrenheit is:", fahrenheit)
# Out:
# The temperature in Fahrenheit is: 150.8

# %%
'''Write a program to demonstrate all arithmetic operators on two numbers. '''
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
print("Modulus:", num1 % num2)
print("Exponentiation:", num1 ** num2)
# Out:
# Addition: 68.0
# Subtraction: -22.0
# Multiplication: 1035.0
# Division: 0.5111111111111111
# Modulus: 23.0
# Exponentiation: 1.8956258430116204e+61

# %%
'''Write a program to check whether a given number is positive, negative, or zero. '''
number = float(input("Enter a number: "))
if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The number is positive.

# %%
'''Write a program to calculate the area and perimeter of a rectangle. '''
length = float(input("Enter the length of the rectangle: "))
breadth = float(input("Enter the breadth of the rectangle: "))
area = length * breadth
perimeter = 2 * (length + breadth)
print("The area of the rectangle is:", area)
print("The perimeter of the rectangle is:", perimeter)
# Out:
# The area of the rectangle is: 1012.0
# The perimeter of the rectangle is: 134.0
