# %%
num = float(input("Enter a number: "))
if num >= 0:
    print(num, "Positive number")
else:
    print(num, "Negative number")
# Out:
# 24.0 Positive number

# %%
marks = float(input("Enter the marks obtained: "))
if marks >= 40:
    print("Pass you got ", marks)
else:
    print("Fail you got ", marks)
# Out:
# Pass you got  76.0

# %%
Age = int(input("Enter your age: "))
if Age >= 18:
    print(Age, "You are eligible to vote")
else:
    print(Age, "You are not eligible to vote")
# Out:
# 56 You are eligible to vote

# %%
Num = float(input("Enter a number: "))
if Num % 2 == 0:
    print(Num, "is Even number")
else:
    print(Num, "is Odd number")
# Out:
# 23.0 is Odd number

# %%
#Check whether a given character is an alphabet or consonant or special character
char = input("Enter a character: ")
if (char >= 'a' and char <= 'z') or (char >= 'A' and char <= 'Z'):
    if char in 'aeiouAEIOU':
        print(char, "is a vowel")
    else:
        print(char, "is a consonant")
else:
    print(char, "is a special character")
# Out:
# # is a special character

# %%
#Write a program to classify a number as positive, negative or zero
num = float(input("Enter a number: "))
if num > 0:
    print(num, "is a Positive number")
elif num == 0:
    print(num, "is Zero")
else:
    print(num, "is a Negative number")
# Out:
# 23.0 is a Positive number

# %%
Unit = int(input("Enter the number of units consumed: "))
if Unit <= 100:
    bill = Unit * 5
elif Unit <= 200:
    bill = Unit * 7
else:
    Unit > 200
    bill = Unit * 10
print("The total electricity bill is: ", bill)
# Out:
# The total electricity bill is:  707

# %%
#Check login Status
username = input("Enter username: ")
password = input("Enter password: ")
if username == "admin" and password == "password123":
    print("Login Successful")
else:
    print("Login Failed")
