# %%
# Write a program to create a list of integers and find the largest and smallest integers in the list.
numbers = [10, 5, 20, 3, 15, 8]
largest = max(numbers)
smallest = min(numbers)
print("Largest number:", largest)
print("Smallest number:", smallest)
# Out:
# Largest number: 20
# Smallest number: 3

# %%
# Write a program to perform insertion and deletion operations on a list. 
my_list = [1, 2, 3, 4, 5]
# Insertion
my_list.append(6)  # Adding an element at the end of the list
print("List after insertion:", my_list)
# Deletion
my_list.remove(3)  # Removing the element '3' from the list
print("List after deletion:", my_list)
# Out:
# List after insertion: [1, 2, 3, 4, 5, 6]
# List after deletion: [1, 2, 4, 5, 6]

# %%
# Write a program to remove duplicates elements from a list and print the unique elements. 
my_list = [1, 2, 3, 4, 5, 2, 3, 6, 7, 8]
unique_list = list(set(my_list))
print("Unique elements:", unique_list)
# Out:
# Unique elements: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Write a program to remove duplicates elements from a list and print the unique elements using for loop taking user input.
user_input = input("Enter elements of the list separated by spaces: ")
my_list = user_input.split()
unique_list = []
for item in my_list:
    if item not in unique_list:
        unique_list.append(item)
print("Unique elements:", unique_list)
# Out:
# Unique elements: ['1,6,,2,5,7,3,12,3,67,']

# %%
# Write a program to sort a list without using built-in sort function.
my_list = [64, 34, 25, 12, 22, 11, 90]
n = len(my_list)
for i in range(n):
    for j in range(0, n - i - 1):
        if my_list[j] > my_list[j + 1]:
            my_list[j], my_list[j + 1] = my_list[j + 1], my_list[j]
print("Sorted list:", my_list)
# Out:
# Sorted list: [11, 12, 22, 25, 34, 64, 90]

# %%
# Write a program to merge two list and remove duplicates.  
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
merged_list = list1 + list2
unique_list = list(set(merged_list))
print("Merged list without duplicates:", unique_list)
# Out:
# Merged list without duplicates: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
#Write a program to search an element in a list using linear search.
my_list = [10, 20, 30, 40, 50]
search_element = int(input("Enter the element to search: "))
found = False
for i in range(len(my_list)):
    if my_list[i] == search_element:
        print(f"Element {search_element} found at index {i}")
        found = True
        break
if not found:
    print(f"Element {search_element} not found in the list")
# Out:
# Element 1 not found in the list

# %%
list = [1, 2, 3, 4, 5 ]
for i in range(len(list)):
    for j in range(i+1, len(list)):
        if list[i] < list[j]:
            list[i], list[j] = list[j], list[i]
print(list)
# Out:
# [5, 4, 3, 2, 1]

# %%
# Write a program to store daily temperature of a city for 7 days in a list and find
# 1. Highest temperature
# 2. Lowest temperature
# 3. Average temperature 
temperatures = []
for i in range(7):
    temp = float(input(f"Enter temperature for day {i+1}: "))
    temperatures.append(temp)
highest_temp = max(temperatures)
lowest_temp = min(temperatures)
average_temp = sum(temperatures) / len(temperatures)
print("Highest temperature:", highest_temp)
print("Lowest temperature:", lowest_temp)
print("Average temperature:", average_temp)
# Out:
# Highest temperature: 87.0
# Lowest temperature: 12.0
# Average temperature: 45.285714285714285

# %%
# Write a program to manage a shopping cart:
# 1. Add items
# 2. Remove items
# 3. Display final cart items
shopping_cart = []
while True:
    print("1. Add item")
    print("2. Remove item")
    print("3. Display cart")
    print("4. Exit")
    choice = input("Enter your choice: ")
    
    if choice == '1':
        item = input("Enter item to add: ")
        shopping_cart.append(item)
        print(f"{item} added to cart.")
        
    elif choice == '2':
        item = input("Enter item to remove: ")
        if item in shopping_cart:
            shopping_cart.remove(item)
            print(f"{item} removed from cart.")
        else:
            print(f"{item} not found in cart.")
            
    elif choice == '3':
        print("Cart items:", shopping_cart)
        
    elif choice == '4':
        print("Exiting...")
        break
        
    else:
        print("Invalid choice. Please try again.")
# Out:
# 1. Add item
# 2. Remove item
# 3. Display cart
# 4. Exit
# 2 added to cart.
# 1. Add item
# 2. Remove item
# 3. Display cart
# 4. Exit
# Cart items: ['2']
# 1. Add item
# 2. Remove item
# 3. Display cart
# 4. Exit
# 3 added to cart.
# 1. Add item
# 2. Remove item
# 3. Display cart
# 4. Exit
# Cart items: ['2', '3']
# 1. Add item
# 2. Remove item
# 3. Display cart
# 4. Exit
# Exiting...
