# %%
# Write a program to identify unique visitors to a website from a list of IP addresses.
IP_addresses = [
    "192.168.1.1",
    "192.168.1.2",
    "192.168.1.3",
    "192.168.1.4",
    "192.168.1.5",
    "192.168.1.3",  # Duplicate IP
    "192.168.1.6",
    "192.168.1.7"
]

# Find unique IP addresses
unique_ips = set(IP_addresses)
print("Unique IP addresses:")
for ip in unique_ips: 
    print(ip)
# Out:
# Unique IP addresses:
# 192.168.1.6
# 192.168.1.4
# 192.168.1.5
# 192.168.1.7
# 192.168.1.3
# 192.168.1.1
# 192.168.1.2

# %%
# Write a program to compare skills of two job candidates and find 
# common skills
# Unique skills between
candidate1_skills = {"Python", "Java", "SQL", "Machine Learning"}
candidate2_skills = {"Python", "JavaScript", "SQL", "Data Analysis"}

# Find common skills
common_skills = candidate1_skills & candidate2_skills
print("Common skills:", common_skills)

# Find unique skills for each candidate
unique_to_candidate1 = candidate1_skills - candidate2_skills
unique_to_candidate2 = candidate2_skills - candidate1_skills
print("Unique to Candidate 1:", unique_to_candidate1)
print("Unique to Candidate 2:", unique_to_candidate2)
# Out:
# Common skills: {'SQL', 'Python'}
# Unique to Candidate 1: {'Machine Learning', 'Java'}
# Unique to Candidate 2: {'JavaScript', 'Data Analysis'}

# %%
Voter_IDs = ["Voter1", "Voter2", "Voter3", "Voter4", "Voter3"]
unique_voters = set(Voter_IDs)
print("Unique Voter IDs:")
for voter in unique_voters:
    print(voter)
# Out:
# Unique Voter IDs:
# Voter4
# Voter1
# Voter3
# Voter2

# %%
BCA = ['Data Science', 'Software', 'Cloude']
MCA = ['Data Science', 'Software', 'AI']
Uni = set(BCA) - set(MCA)
print(Uni)
# Out:
# {'Cloude'}

# %%
Users = ['Abhi', 'Sam', 'Ram']
print(len(Users))
print(set(Users))
# Out:
# 3
# {'Sam', 'Ram', 'Abhi'}
