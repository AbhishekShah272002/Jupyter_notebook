# %%
# Write a program to demonstrate all arithmetic operators on two numbers.
a = 10
b = 5
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
print("Floor Division:", a // b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# Exponentiation: 100000
# Floor Division: 2

# %%
#Write a program using lambda function to find square of a number and print the result.
square = lambda x: x ** 2
number = 4
result = square(number) 
print("square of", number, "is", result)
# Out:
# square of 4 is 16

# %%
# Write a program to store coordinates of a location (latitude, longitude) and display them in readable format.
latitude = 40.7128
longitude = -74.0060
print(f"Coordinates: {latitude}, {longitude}")
# Out:
# Coordinates: 40.7128, -74.006

# %%
# Write a program to maintain attendance of students and count Present and Absent students.
attendance = {
    "Alice": "Present",
    "Bob": "Absent",
    "Charlie": "Present",
    "David": "Absent"
}
present_count = sum(1 for status in attendance.values() if status == "Present")
absent_count = sum(1 for status in attendance.values() if status == "Absent")
print("Present students:", present_count)
print("Absent students:", absent_count)
# Out:
# Present students: 2
# Absent students: 2

# %%
# Write a program to store daily temperatures of a city for 7 days and find Highest, Lowest, and Average temperature
temperatures = [30, 32, 28, 31, 29, 27, 33]
highest_temp = max(temperatures)
lowest_temp = min(temperatures)
average_temp = sum(temperatures) / len(temperatures)
print("Highest Temperature:", highest_temp)
print("Lowest Temperature:", lowest_temp)
print("Average Temperature:", average_temp)
# Out:
# Highest Temperature: 33
# Lowest Temperature: 27
# Average Temperature: 30.0

# %%
# write a program to use break and continue statements while printing numbers from 1 to 20 (skip multiples of 5).
for i in range(1, 21):
    if i % 5 == 0:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19

# %%
# Write a program to use built-in math module to calculate square root and factorial.
import math
number = 16
sqrt_result = math.sqrt(number)
factorial_result = math.factorial(5)
print("Square root of", number, "is", sqrt_result)
print("Factorial of 5 is", factorial_result)
# Out:
# Square root of 16 is 4.0
# Factorial of 5 is 120

# %%
# Write a program to store daily temperatures of a city for 7 days and find Highest, Lowest, and Average temperature.
temperatures = [30, 32, 28, 31, 29, 27, 33]
highest_temp = max(temperatures)
lowest_temp = min(temperatures)
average_temp = sum(temperatures) / len(temperatures)
print("Highest Temperature:", highest_temp)
print("Lowest Temperature:", lowest_temp)
print("Average Temperature:", average_temp)
# Out:
# Highest Temperature: 33
# Lowest Temperature: 27
# Average Temperature: 30.0

# %%
# Write a program to use random module to generate OTP of 6 digits.
import random
otp = random.randint(100000, 999999)
print("Generated OTP:", otp)
# Out:
# Generated OTP: 626585

# %%
# Write a program to convert a tuple into a list and vice versa
my_tuple = (1, 2, 3, 4, 5)
my_list = list(my_tuple)
print("Tuple:", my_tuple)
print("Converted to List:", my_list)
my_list = [1, 2, 3, 4, 5]
my_tuple = tuple(my_list)
print("List:", my_list)
print("Converted to Tuple:", my_tuple)
# Out:
# Tuple: (1, 2, 3, 4, 5)
# Converted to List: [1, 2, 3, 4, 5]
# List: [1, 2, 3, 4, 5]
# Converted to Tuple: (1, 2, 3, 4, 5)

# %%
# Write a program to search an element in a list using linear search.
def linear_search(lst, target):
    for index, element in enumerate(lst):
        if element == target:
            return index
    return -1
my_list = [10, 20, 30, 40, 50]
target = 30
result = linear_search(my_list, target)
if result != -1:
    print(f"Element {target} found at index {result}.")
else:    print(f"Element {target} not found in the list.")
# Out:
# Element 30 found at index 2.
